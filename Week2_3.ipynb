# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51259/Competitive-Programming-B19-/blob/main/Week2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fibonacci(n, memo={}):
    if n in memo:
        return memo[n]
    if n == 0:
        return 0
    if n == 1:
        return 1
    memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
    return memo[n]
n = int(input())
result = fibonacci(n)
print(result)
# Out:
# 15
# 610
